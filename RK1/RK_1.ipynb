# %% [markdown]
# # Контрольный рубеж 1

# %% [markdown]
# ## 1. Команды Linux

# %% [markdown]
# В каталоге **sandbox** находятся три файла: **Task_1, Task_2, Task_3**. Написать последовательность команд в командном интерпретаторе для получения следующих результатов.
# 1. Посмотреть объем файлов **Task_1, Task_2, Task_3** в Кб, изменить название файлов на **Task_first, Task_second, Task_third**. Дописать содержимое файла **Task_first** в конец файла **Task_third**.
# 2. Список всех выполняемых процессов переписать в файл Task_1. Создать в каталоге **sandbox** каталог **sandbox-2**, переместить туда файлы **Task_2, Task_3**. Переписать содержимое файла **/bin/ls** в файл **Task_2**, переименовав его в "**myls**", установить права доступа на файл "**myls**" - "**r-xr--r--**". Добавить в файл **Task_3** информацию о ядре системы.
# 3. В каталоге sandbox создать архив "**MyArch.tar**", добавив туда файлы **Task_1, Task_2, Task_3**, использовать утилиту **gzip** для сжатия архива. Перенаправить содержимое каталога **sandbox**, получаемое командой **ls** в файл **List**. Добавить файл **List** в архив.
# 4. В каталоге **sandbox** создать жесткую ссылку на файл **Task_1** и символическую ссылку на **Task_2**. Получить подробный отчет о содержимом текущего каталога и направить его в файл **Task_3**.
# 5. Создать в каталоге sandbox каталог tmp, скопировать туда все файлы из каталога **/bin**, название которых начинается на символ "**l**". Записать к файл **Task_1** количество файлов в каталоге **tmp**.

# %% [markdown]
# ## 2. Вычислительные задачи

# %% [markdown]
# 1. Разработать программу на языке ассемблера, которая принимает в качестве параметра командной строки значение $2n+1$, выполняет расчет указанного выражения и выводит результат на экран:
# $$1+3+5+7+\ldots +(2n+1)$$
# Если пользователь ввел четное число, программа должна выдать ошибку.
# 2. Разработать программу на языке ассемблера, которая принимает в качестве параметра командной строки значение $n$, выполняет расчет указанного выражения и выводит результат на экран:
# $$1+11+111+1111+\ldots+\sum_{k=0}^n 10^k$$
# 3. Разработать программу на языке ассемблера, которая принимает в качестве параметра командной строки значение $n$, выполняет расчет указанного выражения и выводит результат на экран:
# $$1+2+\ldots+11+21+31+\ldots+91+2+12+\ldots$$
# Т.е. суммируются реверсированные числа от 1 до $n$.
# 4. Разработать программу на языке ассемблера, которая принимает два параметра командной строки $n, k$, суммирует все числа от 1 до $n$, у которых сумма цифр равна $k$.
# 5. Разработать программу на языке ассемблера, которая принимает в качестве параметра командной строки значение $n$, выполняет расчет указанного выражения и выводит результат на экран:
# $$\sum_{k=1}^n k\cdot first\_digit(k) $$
# где $first\_digit(k)$ - первая значащая цифра числа  $k$. Например, $first\_digit(56743) = 5$.

# %% [markdown]
# ## 3. Работа с файлами

# %% [markdown]
# 1. Написать программу на языке ассемблера, которая принимает два параметра командной строки: первый -  имя некоторого каталога, второй - некоторое число $n$. Программа заходит в данный каталог и создает $n$ файлов со случайным названием.
# 2. Написать программу на языке ассемблера, которая принимает два параметра командной строки: первый -  имя некоторого каталога name, второй - некоторое число $n$. Программа заходит в данный каталог и создает в нем новый каталог с именем name, далее заходит в каталог ./name/name и создает там новый каталог name, делая так $n$ раз.
# 3. Написать программу на языке ассемблера, которая принимает один параметр командной строки - имя некоторого каталога. Программа выбирает несколько случайных файлов в каталоге и меняет их названия на случайные.
# 4. Написать программу на языке ассемблера, которая принимает один параметр командной строки - имя некоторого каталога. Программа выбирает два случайных файла в каталоге и меняет их содержимое местами (не использовать переименование файлов).
# 5. Написать программу на языке ассемблера, которая принимает один параметр командной строки - имя некоторого каталога. Программа выбирает несколько случайных файлов в каталоге и меняет их права доступа на случайные.

# %% [markdown]
# ## Генерация заданий по варианту

# %%
import random as rd

Variant = 27
rd.seed(Variant)

Numbers_of_problems = [rd.sample(range(5),1)[0]+1, rd.sample(range(5),1)[0]+1, rd.sample(range(5),1)[0]+1]
Numbers_of_problems
# Out:
# [2, 4, 4]
